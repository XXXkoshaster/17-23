# %%
import numpy as np
import pandas as pd
import json
from datetime import datetime
import pickle

# %%
data = pd.read_csv('../data/egrul.csv')
data.head(5)
# Out:
#    id         inn                                               data  \
# 0   1  1001028755  {"data": {"ИНН": "1001028755", "КПП": "7806010...
# 1   2  1001001390  {"data": {"ИНН": "1001001390", "КПП": "1001010...
# 2   3  1001098784  {"data": {"ИНН": "1001098784", "КПП": "1001010...
# 3   4  1001095007  {"data": {"ИНН": "1001095007", "КПП": "1001010...
# 4   5  1001004095  {"data": {"ИНН": "1001004095", "КПП": "1001010...
#
#                    fetched_at
# 0   2025-04-21 13:02:51.38553
# 1  2025-04-21 13:02:51.398212
# 2  2025-04-21 13:02:51.431791
# 3  2025-04-21 13:02:51.439663
# 4  2025-04-21 13:02:51.489868

# %%
data.info()
print(data['data'][0])
json.loads(data['data'][0])
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          15000 non-null  int64
#  1   inn         15000 non-null  int64
#  2   data        15000 non-null  object
#  3   fetched_at  15000 non-null  object
# dtypes: int64(2), object(2)
# memory usage: 468.9+ KB
# {"data": {"ИНН": "1001028755", "КПП": "780601001", "СЧР": 39, "ОГРН": "1111001006698", "ОКПО": "67882274", "ОКФС": {"Код": "16", "Наим": "Частная собственность"}, "РМСП": {"Кат": "МАЛОЕ ПРЕДПРИЯТИЕ", "ДатаВкл": "2016-08-01"}, "ЕФРСБ": [], "ОКАТО": {"Код": "40278000000", "Наим": "Красногвардейский"}, "ОКВЭД": {"Код": "46.73", "Наим": "Торговля оптовая лесоматериалами, строительными материалами и санитарно-техническим оборудованием", "Версия": "2014"}, "ОКОГУ": {"Код": "4210014", "Наим": "Организации, учрежденные юридическими лицами или гражданами, или юридическими лицами и гражданами совместно"}, "ОКОПФ": {"Код": "12300", "Наим": "Общества с ограниченной ответственностью"}, "ОКТМО": {"Код": "40348000000", "Наим": "муниципальный округ Полюстрово"}, "Учред": {"РФ": [], "ФЛ": [{"ИНН": "782611615234", "ФИО": "Трапезников Виктор Борисович", "Доля": {"Номинал": 10000.0, "Процент": 100.0}, "Недост": false, "МассУчред": true, "СвязУчред": ["1131039000718", "1057810297621", "1037811076489", "1144711000015", "1107847386635", "1107847099194", "1167847292546", "1136908000921", "1167847291875", "1144702000024", "1137610003156", "1101001006710", "1137847282517", "5067847089327", "1137847163740", "1137847007726", "1057810012996", "1107847372269", "1121001012032", "1144712000014", "1157847015391", "1107847386646", "1111001003080", "1175321003285", "1101001009163", "1226000000280", "1117847288063", "1077847598399", "1107847099161", "1136952013901", "1107847099216", "1107847386591", "1133525012653"], "ДатаЗаписи": "2011-06-16", "СвязРуковод": ["1037857001555", "1057810297621", "1137847007726", "1137847163740", "1057810012996", "1157847015391", "1117847288063"]}], "ПИФ": [], "ИнОрг": [], "РосОрг": []}, "Лиценз": [], "Налоги": {"СумУпл": "4668452.57", "СведУпл": [{"Наим": "НЕНАЛОГОВЫЕ ДОХОДЫ, администрируемые налоговыми органами", "Сумма": 0.0}, {"Наим": "Суммы пеней", "Сумма": 0.0}, {"Наим": "Налог на имущество организаций", "Сумма": 0.0}, {"Наим": "Страховые и другие взносы на обязательное пенсионное страхование, зачисляемые в Пенсионный фонд Российской Федерации", "Сумма": 4539562.84}, {"Наим": "Страховые взносы на обязательное социальное страхование на случай временной нетрудоспособности и в связи с материнством", "Сумма": 0.0}, {"Наим": "Страховые взносы на обязательное медицинское страхование работающего населения, зачисляемые в бюджет Федерального фонда обязательного медицинского страхования", "Сумма": 98342.73}, {"Наим": "Налог, взимаемый в связи с  применением упрощенной  системы налогообложения", "Сумма": 0.0}, {"Наим": "Налог на прибыль", "Сумма": 0.0}, {"Наим": "Государственная пошлина", "Сумма": 0.0}, {"Наим": "Налог на добавленную стоимость", "Сумма": 30547.0}], "ОсобРежим": [], "СумНедоим": null, "СведУплГод": "2023"}, "РегПФР": {"КодОрг": "078", "ДатаРег": "2014-03-31", "НаимОрг": "Отделение Фонда пенсионного и социального страхования Российской Федерации по Санкт-Петербургу и Ленинградской области", "РегНомер": "1055379976"}, "РегФНС": {"КодОрг": "7847", "НаимОрг": "Межрайонная инспекция Федеральной налоговой службы №15 по Санкт-Петербургу", "АдресОрг": "191124, Санкт-Петербург г, Красного Текстильщика ул, д 10-12 лит. О"}, "РегФСС": {"КодОрг": "078", "ДатаРег": "2019-03-31", "НаимОрг": "Отделение Фонда пенсионного и социального страхования Российской Федерации по Санкт-Петербургу и Ленинградской области", "РегНомер": "1055379976"}, "Регион": {"Код": "78", "Наим": "Санкт-Петербург"}, "СЧРГод": "2024", "Статус": {"Код": "001", "Наим": "Действует"}, "ТекФНС": {"КодОрг": "7806", "НаимОрг": "Межрайонная инспекция Федеральной налоговой службы №21 по Санкт-Петербургу", "ДатаПостУч": "2014-03-27"}, "УпрОрг": {"ИНН": "7806493749", "ОГРН": "1137847007726", "Недост": false, "ИнАдрес": null, "ДатаОГРН": "2013-01-10", "ИнСтрана": null, "НаимПолн": "ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ \"УПРАВЛЯЮЩАЯ КОМПАНИЯ ЭЛЕМЕНТ-ЦЕНТР\"", "НаимСокр": "ООО \"УК ЭЛЕМЕНТ-ЦЕНТР\"", "ИнДатаРег": null, "ДатаЗаписи": "2013-12-31", "ИнРегНомер": null}, "УстКап ...
# {'data': {'ИНН': '1001028755',
#   'КПП': '780601001',
#   'СЧР': 39,
#   'ОГРН': '1111001006698',
#   'ОКПО': '67882274',
#   'ОКФС': {'Код': '16', 'Наим': 'Частная собственность'},
#   'РМСП': {'Кат': 'МАЛОЕ ПРЕДПРИЯТИЕ', 'ДатаВкл': '2016-08-01'},
#   'ЕФРСБ': [],
#   'ОКАТО': {'Код': '40278000000', 'Наим': 'Красногвардейский'},
#   'ОКВЭД': {'Код': '46.73',
#    'Наим': 'Торговля оптовая лесоматериалами, строительными материалами и санитарно-техническим оборудованием',
#    'Версия': '2014'},
#   'ОКОГУ': {'Код': '4210014',
#    'Наим': 'Организации, учрежденные юридическими лицами или гражданами, или юридическими лицами и гражданами совместно'},
#   'ОКОПФ': {'Код': '12300',
#    'Наим': 'Общества с ограниченной ответственностью'},
#   'ОКТМО': {'Код': '40348000000', 'Наим': 'муниципальный округ Полюстрово'},
#   'Учред': {'РФ': [],
#    'ФЛ': [{'ИНН': '782611615234',
#      'ФИО': 'Трапезников Виктор Борисович',
#      'Доля': {'Номинал': 10000.0, 'Процент': 100.0},
#      'Недост': False,
#      'МассУчред': True,
#      'СвязУчред': ['1131039000718',
#       '1057810297621',
#       '1037811076489',
#       '1144711000015',
#       '1107847386635',
#       '1107847099194',
#       '1167847292546',
#       '1136908000921',
#       '1167847291875',
#       '1144702000024',
#       '1137610003156',
#       '1101001006710',
#       '1137847282517',
#       '5067847089327',
#       '1137847163740',
#       '1137847007726',
#       '1057810012996',
#       '1107847372269',
#       '1121001012032',
#       '1144712000014',
#       '1157847015391',
#       '1107847386646',
#       '1111001003080',
#       '1175321003285',
#       '1101001009163',
#       '1226000000280',
#       '1117847288063',
#       '1077847598399',
#       '1107847099161',
#       '1136952013901',
#       '1107847099216',
#       '1107847386591',
#       '1133525012653'],
#      'ДатаЗаписи': '2011-06-16',
#      'СвязРуковод': ['1037857001555',
#       '1057810297621',
#       '1137847007726',
#       '1137847163740',
#       '1057810012996',
#       '1157847015391',
#       '1117847288063']}],
#    'ПИФ': [],
#    'ИнОрг': [],
#    'РосОрг': []},
#   'Лиценз': [],
#   'Налоги': {'СумУпл': '4668452.57',
#    'СведУпл': [{'Наим': 'НЕНАЛОГОВЫЕ ДОХОДЫ, администрируемые налоговыми органами',
#      'Сумма': 0.0},
#     {'Наим': 'Суммы пеней', 'Сумма': 0.0},
#     {'Наим': 'Налог на имущество организаций', 'Сумма': 0.0},
#     {'Наим': 'Страховые и другие взносы на обязательное пенсионное страхование, зачисляемые в Пенсионный фонд Российской Федерации',
#      'Сумма': 4539562.84},
#     {'Наим': 'Страховые взносы на обязательное социальное страхование на случай временной нетрудоспособности и в связи с материнством',
#      'Сумма': 0.0},
#     {'Наим': 'Страховые взносы на обязательное медицинское страхование работающего населения, зачисляемые в бюджет Федерального фонда обязательного медицинского страхования',
#      'Сумма': 98342.73},
#     {'Наим': 'Налог, взимаемый в связи с  применением упрощенной  системы налогообложения',
#      'Сумма': 0.0},
#     {'Наим': 'Налог на прибыль', 'Сумма': 0.0},
#     {'Наим': 'Государственная пошлина', 'Сумма': 0.0},
#     {'Наим': 'Налог на добавленную стоимость', 'Сумма': 30547.0}],
#    'ОсобРежим': [],
#    'СумНедоим': None,
#    'СведУплГод': '2023'},
#   'РегПФР': {'КодОрг': '078',
#    'ДатаРег': '2014-03-31',
#    'НаимОрг': 'Отделение Фонда пенсионного и социального страхования Российской Федерации по Санкт-Петербургу и Ленинградской области',
#    'РегНомер': '1055379976'},
#   'РегФНС': {'КодОрг': '7847',
#    'НаимОрг': 'Межрайонная инспекция Федеральной налоговой службы №15 по Санкт-Петербургу',
#    'АдресОрг': '191124, Санкт-Петербург г, Красного Текстильщика ул, д 10-12 лит. О'},
#   'РегФСС': {'КодОрг': '078',
#    'ДатаРег': '2019-03-31',
#    'НаимОрг': 'Отделение Фонда пенсионного и социального страхования Российской Федерации по Санкт-Петербургу и Ленинградской области',
#    'РегНомер': '1055379976'},
#   'Регион': {'Код': '78', 'Наим': 'Санкт-Петербург'},
#   'СЧРГод': '2024',
#   'Статус': {'Код': '001', 'Наим': 'Действует'},
#   'ТекФНС': {'КодОрг': '7806',
#    'НаимОрг': 'Межрайонная инспекция Федеральной налоговой службы №21 по Санкт-Петербургу',
#    'ДатаПостУч': '2014-03-27'},
#   'УпрОрг': {'ИНН': '7806493749',
#    'ОГРН': '1137847007726',
#    'Недост': False,
#    'ИнАдрес': None,
#    'ДатаОГРН': '2013-01-10',
#    'ИнСтрана': None,
#    'НаимПолн': 'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "УПРАВЛЯЮЩАЯ КОМПАНИЯ ЭЛЕМЕНТ-ЦЕНТР"',
#    'НаимСокр': 'ООО "УК ЭЛЕМЕНТ-ЦЕНТР"',
#    'ИнДатаРег': None,
#    'ДатаЗаписи': '2013-12-31',
#    'ИнРегНомер': None},
#   'УстКап': {'Тип': 'УСТАВНЫЙ КАПИТАЛ', 'Сумма': 10000},
#   'ДатаВып': '2025-01-12',
#   'ДатаРег': '2011-06-16',
#   'Подразд': {},
#   'Руковод': [],
#   'Санкции': False,
#   'ЮрАдрес': {'ИдГАР': None,
#    'Недост': False,
#    'АдресРФ': '195067, г. Санкт-Петербург, пр-кт Шафировский, д. 17, литер О, офис 7',
#    'НасПункт': 'г. Санкт-Петербург',
#    'МассАдрес': False},
#   'ДатаОГРН': '2011-06-16',
#   'Контакты': {'Тел': ['+78142593300', '+78142533666', '+78123205388'],
#    'Емэйл': ['account@elementsm.ru'],
#    'ВебСайт': 'http://bsk-element.ru'},
#   'НаимАнгл': None,
#   'НаимПолн': 'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ЭЛЕМЕНТ СЕВЕРО-ЗАПАД"',
#   'НаимСокр': 'ООО "ЭЛЕМЕНТ СЕВЕРО-ЗАПАД"',
#   'ОКВЭДДоп': [{'Код': '46.1',
#     'Наим': 'Торговля оптовая за вознаграждение или на договорной основе',
#     'Версия': '2014'},
#    {'Код': '46.4',
#     'Наим': 'Торговля оптовая непродовольственными потребительскими товарами',
#     'Версия': '2014'},
#    {'Код': '46.7',
#     'Наим': 'Торговля оптовая специализированная прочая',
#     'Версия': '2014'},
#    {'Код': '47.1',
#     'Наим': 'Торговля розничная в неспециализированных магазинах',
#     'Версия': '2014'},
#    {'Код': '47.5',
#     'Наим': 'Торговля розничная прочими бытовыми изделиями в специализированных магазинах',
#     'Версия': '2014'}],
#   'ДисквЛица': False,
#   'МассУчред': True,
#   'НедобПост': False,
#   'СвязУчред': [],
#   'ТоварЗнак': [],
#   'НелегалФин': False,
#   'ПоддержМСП': [{'ИНН': '7710349494',
#     'Тип': 'Предоставление финансирования на возвратной основе',
#     'Дата': '2020-08-07',
#     'Наруш': False,
#     'Форма': 'Финансовая поддержка',
#     'Размер': '7.0 %',
#     'НаимОрг': 'МИНИСТЕРСТВО ЭКОНОМИЧЕСКОГО РАЗВИТИЯ РОССИЙСКОЙ ФЕДЕРАЦИИ'}],
#   'Правопредш': [{'ИНН': '7806429736',
#     'ОГРН': '1107847099161',
#     'НаимПолн': 'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "РЕСУРС 3"'},
#    {'ИНН': '7806429750',
#     'ОГРН': '1107847099216',
#     'НаимПолн': 'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "РЕСУРС 4"'}],
#   'Правопреем': [],
#   'СвязУпрОрг': [],
#   'МассРуковод': False,
#   'ДержРеестрАО': {}},
#  'meta': {'status': 'ok', 'balance': 5352.1, 'today_request_count': 2152}}

# %%
data['data'] = data['data'].apply(json.loads)

# %%
df_expanded = pd.json_normalize(data['data'], max_level = 5)
df_expanded.columns = [col.replace('.', '_') for col in df_expanded.columns]
print([i for i  in df_expanded.columns])
# Out:
# ['data.ИНН', 'data.КПП', 'data.СЧР', 'data.ОГРН', 'data.ОКПО', 'data.ОКФС.Код', 'data.ОКФС.Наим', 'data.РМСП.Кат', 'data.РМСП.ДатаВкл', 'data.ЕФРСБ', 'data.ОКАТО.Код', 'data.ОКАТО.Наим', 'data.ОКВЭД.Код', 'data.ОКВЭД.Наим', 'data.ОКВЭД.Версия', 'data.ОКОГУ.Код', 'data.ОКОГУ.Наим', 'data.ОКОПФ.Код', 'data.ОКОПФ.Наим', 'data.ОКТМО.Код', 'data.ОКТМО.Наим', 'data.Учред.РФ', 'data.Учред.ФЛ', 'data.Учред.ПИФ', 'data.Учред.ИнОрг', 'data.Учред.РосОрг', 'data.Лиценз', 'data.Налоги.СумУпл', 'data.Налоги.СведУпл', 'data.Налоги.ОсобРежим', 'data.Налоги.СумНедоим', 'data.Налоги.СведУплГод', 'data.РегПФР.КодОрг', 'data.РегПФР.ДатаРег', 'data.РегПФР.НаимОрг', 'data.РегПФР.РегНомер', 'data.РегФНС.КодОрг', 'data.РегФНС.НаимОрг', 'data.РегФНС.АдресОрг', 'data.РегФСС.КодОрг', 'data.РегФСС.ДатаРег', 'data.РегФСС.НаимОрг', 'data.РегФСС.РегНомер', 'data.Регион.Код', 'data.Регион.Наим', 'data.СЧРГод', 'data.Статус.Код', 'data.Статус.Наим', 'data.ТекФНС.КодОрг', 'data.ТекФНС.НаимОрг', 'data.ТекФНС.ДатаПостУч', 'data.УпрОрг.ИНН', 'data.УпрОрг.ОГРН', 'data.УпрОрг.Недост', 'data.УпрОрг.ИнАдрес', 'data.УпрОрг.ДатаОГРН', 'data.УпрОрг.ИнСтрана', 'data.УпрОрг.НаимПолн', 'data.УпрОрг.НаимСокр', 'data.УпрОрг.ИнДатаРег', 'data.УпрОрг.ДатаЗаписи', 'data.УпрОрг.ИнРегНомер', 'data.УстКап.Тип', 'data.УстКап.Сумма', 'data.ДатаВып', 'data.ДатаРег', 'data.Руковод', 'data.Санкции', 'data.ЮрАдрес.ИдГАР', 'data.ЮрАдрес.Недост', 'data.ЮрАдрес.АдресРФ', 'data.ЮрАдрес.НасПункт', 'data.ЮрАдрес.МассАдрес', 'data.ДатаОГРН', 'data.Контакты.Тел', 'data.Контакты.Емэйл', 'data.Контакты.ВебСайт', 'data.НаимАнгл', 'data.НаимПолн', 'data.НаимСокр', 'data.ОКВЭДДоп', 'data.ДисквЛица', 'data.МассУчред', 'data.НедобПост', 'data.СвязУчред', 'data.ТоварЗнак', 'data.НелегалФин', 'data.ПоддержМСП', 'data.Правопредш', 'data.Правопреем', 'data.СвязУпрОрг', 'data.МассРуковод', 'meta.status', 'meta.balance', 'meta.today_request_count', 'data.Налоги.НедоимДата', 'data.ДержРеестрАО.ИНН', 'data.ДержРеестрАО.ОГРН', 'data.ДержРеестрАО.НаимПолн', 'data.Статус.ДатаЗаписи', 'data.Контакты.ВК', 'data.Ликвид.Дата', 'data.Ликвид.Наим', 'data.Контакты.Телеграм', 'data.Подразд.Филиал', 'data.Подразд.Представ', 'data.СанкцииСтраны', 'data.НедобПостЗап', 'data.ЮрАдрес.НедостОпис', 'data.ЮрАдрес.НедостДатаЗаписи', 'data.НелегалФинСтатус']

# %%
print(df_expanded.values)
# Out:
# [['1001028755' '780601001' 39 ... nan nan nan]
#  ['1001001390' '100101001' 163 ... nan nan nan]
#  ['1001098784' '100101001' 4 ... nan nan nan]
#  ...
#  ['9731052434' '772201001' 15 ... nan nan nan]
#  ['9731060192' '773101001' 37 ... nan nan nan]
#  ['9901036545' '990101001' 9 ... nan nan nan]]

# %%
features = pd.DataFrame()
features['inn'] = df_expanded['data_ИНН']

# %%
features['categori'] = df_expanded['data_РМСП_Кат']

# %%
# 1. Возраст компании (в годах)
df_expanded['ДатаРег'] = pd.to_datetime(df_expanded['data_ДатаРег'], errors='coerce')
df_expanded['Возраст_компании'] = ((datetime.now() - df_expanded['ДатаРег']).dt.days // 365).fillna(-1)

# 2. Статус компании
df_expanded['Статус'] = df_expanded['data_Статус_Наим'].fillna('data_Неизвестно')

# 3. Недостоверный юридический адрес
df_expanded['Недостоверный_адрес'] = df_expanded['data_ЮрАдрес_Недост'].fillna(False)

# 4. Сумма налоговой недоимки
df_expanded['Сумма_налоговой_недоимки'] = df_expanded['data_Налоги_СумНедоим'].fillna(0).astype(float)

# 5. Сумма уплаченных налогов
df_expanded['Сумма_уплаченных_налогов'] = df_expanded['data_Налоги_СумУпл'].fillna(0).astype(float)

# 6. Применение особого налогового режима
df_expanded['Особый_налоговый_режим'] = df_expanded['data_Налоги_ОсобРежим'].apply(lambda x: 1 if isinstance(x, list) and len(x) > 0 else 0)

# 7. Массовый руководитель
df_expanded['Массовый_руководитель'] = df_expanded['data_МассРуковод'].fillna(False)

# 8. Дисквалифицированный руководитель
df_expanded['Дисквалифицированный_руководитель'] = df_expanded['data_ДисквЛица'].fillna(False)

# 9. Недостоверные сведения о руководстве
df_expanded['Недостоверный_руководитель'] = df_expanded['data_Руковод'].apply(
    lambda x: any(d.get('Недост', False) for d in x) if isinstance(x, list) else False
)

# 10. Массовые учредители
df_expanded['Массовый_учредитель'] = df_expanded['data_МассУчред'].fillna(False)

# 11. Наличие записей о банкротстве
df_expanded['Есть_банкротство'] = df_expanded['data_ЕФРСБ'].apply(lambda x: 1 if isinstance(x, list) and len(x) > 0 else 0)

# 12. Включение в реестр недобросовестных поставщиков
df_expanded['Недобросовестный_поставщик'] = df_expanded['data_НедобПост'].fillna(False)

# 13. Наличие санкций
df_expanded['Под_санкциями'] = df_expanded['data_Санкции'].fillna(False)

# 14. Категория предприятия
df_expanded['Категория_МСП'] = df_expanded['data_РМСП_Кат'].fillna('Неизвестно')

# 15. Среднесписочная численность работников
df_expanded['Среднесписочная_численность'] = df_expanded['data_СЧР'].fillna(0)

df_expanded.to_excel('data.xlsx', index=False)
